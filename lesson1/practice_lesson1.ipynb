# %%
import numpy as np
import pandas as pd
pd.set_option("display.precision", 2)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fab306b8-e8a7-44d1-bcd6-2524d04f830e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fab306b8-e8a7-44d1-bcd6-2524d04f830e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BigML_Dataset_60144212e84f9471590003a4.csv to BigML_Dataset_60144212e84f9471590003a4.csv

# %%
import io
tele_data = pd.read_csv(io.BytesIO(uploaded["BigML_Dataset_60144212e84f9471590003a4.csv"]))

# %%
tele_data.head()
# Out:
#   state  account length  ...  customer service calls  churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 21 columns]

# %%
tele_data.shape
# Out:
# (3333, 21)

# %%
tele_data.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
tele_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
tele_data["churn"] = tele_data["churn"].astype("int64")

# %%
tele_data.describe()
# Out:
#        account length  area code  ...  customer service calls    churn
# count         3333.00    3333.00  ...                 3333.00  3333.00
# mean           101.06     437.18  ...                    1.56     0.14
# std             39.82      42.37  ...                    1.32     0.35
# min              1.00     408.00  ...                    0.00     0.00
# 25%             74.00     408.00  ...                    1.00     0.00
# 50%            101.00     415.00  ...                    1.00     0.00
# 75%            127.00     510.00  ...                    2.00     0.00
# max            243.00     510.00  ...                    9.00     1.00
#
# [8 rows x 17 columns]

# %%
tele_data.describe(include = ["bool", "object"])
# Out:
#        state phone number international plan voice mail plan
# count   3333         3333               3333            3333
# unique    51         3333                  2               2
# top       WV     420-2000                 no              no
# freq     106            1               3010            2411

# %%
tele_data["churn"].value_counts()
# Out:
# 0    2850
# 1     483
# Name: churn, dtype: int64

# %%
tele_data["area code"].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: area code, dtype: int64

# %%
tele_data.sort_values(by = "total day charge", ascending = False)
# Out:
#      state  account length  ...  customer service calls churn
# 365     CO             154  ...                       1     1
# 985     NY              64  ...                       1     1
# 2594    OH             115  ...                       1     1
# 156     OH              83  ...                       0     1
# 605     MO             112  ...                       2     1
# ...    ...             ...  ...                     ...   ...
# 1986    WI              70  ...                       0     0
# 2753    OH             134  ...                       2     0
# 2736    OK             127  ...                       3     0
# 1397    VT             101  ...                       1     0
# 1345    SD              98  ...                       4     1
#
# [3333 rows x 21 columns]

# %%
tele_data.sort_values(by = ["total day charge", "total day minutes"], ascending = [True, True])
# Out:
#      state  account length  ...  customer service calls churn
# 1345    SD              98  ...                       4     1
# 1397    VT             101  ...                       1     0
# 2736    OK             127  ...                       3     0
# 2753    OH             134  ...                       2     0
# 1986    WI              70  ...                       0     0
# ...    ...             ...  ...                     ...   ...
# 605     MO             112  ...                       2     1
# 156     OH              83  ...                       0     1
# 2594    OH             115  ...                       1     1
# 985     NY              64  ...                       1     1
# 365     CO             154  ...                       1     1
#
# [3333 rows x 21 columns]

# %%
tele_data["churn"].std()
# Out:
# 0.35206742362412946

# %%
tele_data[tele_data["churn"] == 1]
# Out:
#      state  account length  ...  customer service calls churn
# 10      IN              65  ...                       4     1
# 15      NY             161  ...                       4     1
# 21      CO              77  ...                       5     1
# 33      AZ              12  ...                       1     1
# 41      MD             135  ...                       0     1
# ...    ...             ...  ...                     ...   ...
# 3301    CA              84  ...                       0     1
# 3304    IL              71  ...                       4     1
# 3320    GA             122  ...                       4     1
# 3322    MD              62  ...                       4     1
# 3323    IN             117  ...                       5     1
#
# [483 rows x 21 columns]

# %%
tele_data[tele_data["churn"] == 1]["total day minutes"].medesan()
# Out:
# 206.91407867494814

# %%
tele_data[(tele_data["churn"] == 1) & (tele_data["international plan"] == "no")]["total intl minutes"]
# Out:
# 10      12.7
# 15       5.4
# 21       5.7
# 33      11.8
# 48       8.8
#         ...
# 3280    10.0
# 3287    10.9
# 3301    10.4
# 3322    11.5
# 3323    13.6
# Name: total intl minutes, Length: 346, dtype: float64

# %%
tele_data.iloc[0:3, 0:3]
# Out:
#   state  account length  area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415

# %%
tele_data.head()
# Out:
#   state  account length  ...  customer service calls churn
# 0    KS             128  ...                       1     0
# 1    OH             107  ...                       1     0
# 2    NJ             137  ...                       0     0
# 3    OH              84  ...                       2     0
# 4    OK              75  ...                       3     0
#
# [5 rows x 21 columns]

# %%
tele_data.loc[0:3, "state":"phone number"]
# Out:
#   state  account length  area code phone number
# 0    KS             128        415     382-4657
# 1    OH             107        415     371-7191
# 2    NJ             137        415     358-1921
# 3    OH              84        408     375-9999

# %%
tele_data[-1:]
# Out:
#      state  account length  ...  customer service calls churn
# 3332    TN              74  ...                       0     0
#
# [1 rows x 21 columns]

# %%
tele_data[:1]
# Out:
#   state  account length  ...  customer service calls churn
# 0    KS             128  ...                       1     0
#
# [1 rows x 21 columns]

# %%
tele_data.apply(np.max)
# Out:
# state                           WY
# account length                 243
# area code                      510
# phone number              422-9964
# international plan             yes
# voice mail plan                yes
# number vmail messages           51
# total day minutes          3.5e+02
# total day calls                165
# total day charge                60
# total eve minutes          3.6e+02
# total eve calls                170
# total eve charge                31
# total night minutes          4e+02
# total night calls              175
# total night charge              18
# total intl minutes              20
# total intl calls                20
# total intl charge              5.4
# customer service calls           9
# churn                            1
# dtype: object

# %%
tele_data[tele_data["State"][0] == 'W']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-a8d479b8598c> in <module>()
# ...
